# %%
import warnings
warnings.filterwarnings('ignore')

TARGET = 'quality'
DISCOVERY_TIMEOUT_SECONDS=2800
ESTIMATION_TIMEOUT_SECONDS=1800
REFUTATION_GLOBAL_TIMEOUT_SECONDS=1800
REFUTATION_MODEL_TIMEOUT_SECONDS=240

# %% [markdown]
# # Dataset and Knowledge settings

# %%
import pandas as pd

df = pd.read_csv('./resources/wine_quality/data.csv')
df['quality'] = df['quality'].astype(float)
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0   0.9978  3.51       0.56
# 1                    25.0                  67.0   0.9968  3.20       0.68
# 2                    15.0                  54.0   0.9970  3.26       0.65
# 3                    17.0                  60.0   0.9980  3.16       0.58
# 4                    11.0                  34.0   0.9978  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0   0.9911  3.27       0.50
# 6493                 57.0                 168.0   0.9949  3.15       0.46
# 6494                 30.0                 111.0   0.9925  2.99       0.46
# 6495                 20.0                 110.0   0.9887  3.34       0.38
# 6496                 22.0                  98.0   0.9894  3.26       0.32
#
#       alcohol  quality   type
# 0         9.4      5.0    red
# 1         9.8      5.0    red
# 2         9.8      5.0    red
# 3         9.8      6.0    red
# 4         9.4      5.0    red
# ...       ...      ...    ...
# 6492     11.2      6.0  white
# 6493      9.6      5.0  white
# 6494      9.4      6.0  white
# 6495     12.8      7.0  white
# 6496     11.8      6.0  white
#
# [6497 rows x 13 columns]

# %%
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   float64
#  12  type                  6497 non-null   object
# dtypes: float64(12), object(1)
# memory usage: 660.0+ KB
# None
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987100
# 25%       0.038000            17.000000             77.000000     0.992300
# 50%       0.047000            29.000000            118.000000     0.994900
# 75%       0.065000            41.000000            156.000000     0.997000
# max       0.611000           289.000000            440.000000     1.039000
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
from causal_nest.knowledge import parse_knowledge_file

knowledge = parse_knowledge_file('./resources/wine_quality/knowledge.txt')
knowledge
# Out:
# Knowledge(required_edges=[('alcohol', 'quality'), ('total_sulfur_dioxide', 'quality')], forbidden_edges=[('quality', 'chlorides'), ('quality', 'pH'), ('quality', 'density'), ('quality', 'free_sulfur_dioxide'), ('quality', 'alcohol'), ('quality', 'volatile_acidity'), ('quality', 'sulphates'), ('quality', 'residual_sugar'), ('quality', 'citric_acid'), ('quality', 'fixed_acidity'), ('quality', 'total_sulfur_dioxide')])

# %%
from causal_nest.dataset import MissingDataHandlingMethod, Dataset, handle_missing_data, FeatureTypeMap, FeatureType, estimate_feature_importances

feature_mapping = [FeatureTypeMap(feature=c, type=FeatureType.CONTINUOUS) for c in df.drop(['type', 'quality'], axis=1).columns]

dataset = Dataset(data=df, target=TARGET, feature_mapping=feature_mapping)
dataset = handle_missing_data(dataset, MissingDataHandlingMethod.FORWARD_FILL)
dataset = estimate_feature_importances(dataset)
dataset
# Out:
# Dataset(data=      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0   0.9978  3.51       0.56
# 1                    25.0                  67.0   0.9968  3.20       0.68
# 2                    15.0                  54.0   0.9970  3.26       0.65
# 3                    17.0                  60.0   0.9980  3.16       0.58
# 4                    11.0                  34.0   0.9978  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0   0.9911  3.27       0.50
# 6493                 57.0                 168.0   0.9949  3.15       0.46
# 6494                 30.0                 111.0   0.9925  2.99       0.46
# 6495                 20.0                 110.0   0.9887  3.34       0.38
# 6496                 22.0                  98.0   0.9894  3.26       0.32
#
#       alcohol  quality   type
# 0         9.4      5.0    red
# 1         9.8      5.0    red
# 2         9.8      5.0    red
# 3         9.8      6.0    red
# 4         9.4      5.0    red
# ...       ...      ...    ...
# 6492     11.2      6.0  white
# 6493      9.6      5.0  white
# 6494      9.4      6.0  white
# 6495     12.8      7.0  white
# 6496     11.8      6.0  white
#
# [6497 rows x 13 columns], target='quality', feature_mapping=[FeatureTypeMap(feature='alcohol', type=<FeatureType.CONTINUOUS: 3>, importance=0.25296813144971836), FeatureTypeMap(feature='volatile_acidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.12747149434953053), FeatureTypeMap(feature='free_sulfur_dioxide', type=<FeatureType.CONTINUOUS: 3>, importance=0.09022769786572933), FeatureTypeMap(feature='sulphates', type=<FeatureType.CONTINUOUS: 3>, importance=0.07896145650504846), FeatureTypeMap(feature='total_sulfur_dioxide', type=<FeatureType.CONTINUOUS: 3>, importance=0.07423155145523201), FeatureTypeMap(feature='residual_sugar', type=<FeatureType.CONTINUOUS: 3>, importance=0.07344896313510414), FeatureTypeMap(feature='pH', type=<FeatureType.CONTINUOUS: 3>, importance=0.06738578157748708), FeatureTypeMap(feature='chlorides', type=<FeatureType.CONTINUOUS: 3>, importance=0.06537080664276268), FeatureTypeMap(feature='citric_acid', type=<FeatureType.CONTINUOUS: 3>, importance=0.06004473273518612), FeatureTypeMap(feature='fixed_acidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.055258428032332364), FeatureTypeMap(feature='density', type=<FeatureType.CONTINUOUS: 3>, importance=0.054630956251868826)])

# %%
from causal_nest.problem import Problem

problem = Problem(dataset=dataset, description='Wine Quality', knowledge=knowledge)
problem
# Out:
# Problem(dataset=Dataset(data=      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0   0.9978  3.51       0.56
# 1                    25.0                  67.0   0.9968  3.20       0.68
# 2                    15.0                  54.0   0.9970  3.26       0.65
# 3                    17.0                  60.0   0.9980  3.16       0.58
# 4                    11.0                  34.0   0.9978  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0   0.9911  3.27       0.50
# 6493                 57.0                 168.0   0.9949  3.15       0.46
# 6494                 30.0                 111.0   0.9925  2.99       0.46
# 6495                 20.0                 110.0   0.9887  3.34       0.38
# 6496                 22.0                  98.0   0.9894  3.26       0.32
#
#       alcohol  quality   type
# 0         9.4      5.0    red
# 1         9.8      5.0    red
# 2         9.8      5.0    red
# 3         9.8      6.0    red
# 4         9.4      5.0    red
# ...       ...      ...    ...
# 6492     11.2      6.0  white
# 6493      9.6      5.0  white
# 6494      9.4      6.0  white
# 6495     12.8      7.0  white
# 6496     11.8      6.0  white
#
# [6497 rows x 13 columns], target='quality', feature_mapping=[FeatureTypeMap(feature='alcohol', type=<FeatureType.CONTINUOUS: 3>, importance=0.25296813144971836), FeatureTypeMap(feature='volatile_acidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.12747149434953053), FeatureTypeMap(feature='free_sulfur_dioxide', type=<FeatureType.CONTINUOUS: 3>, importance=0.09022769786572933), FeatureTypeMap(feature='sulphates', type=<FeatureType.CONTINUOUS: 3>, importance=0.07896145650504846), FeatureTypeMap(feature='total_sulfur_dioxide', type=<FeatureType.CONTINUOUS: 3>, importance=0.07423155145523201), FeatureTypeMap(feature='residual_sugar', type=<FeatureType.CONTINUOUS: 3>, importance=0.07344896313510414), FeatureTypeMap(feature='pH', type=<FeatureType.CONTINUOUS: 3>, importance=0.06738578157748708), FeatureTypeMap(feature='chlorides', type=<FeatureType.CONTINUOUS: 3>, importance=0.06537080664276268), FeatureTypeMap(feature='citric_acid', type=<FeatureType.CONTINUOUS: 3>, importance=0.06004473273518612), FeatureTypeMap(feature='fixed_acidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.055258428032332364), FeatureTypeMap(feature='density', type=<FeatureType.CONTINUOUS: 3>, importance=0.054630956251868826)]), description='Wine Quality', ground_truth=None, knowledge=Knowledge(required_edges=[('alcohol', 'quality'), ('total_sulfur_dioxide', 'quality')], forbidden_edges=[('quality', 'chlorides'), ('quality', 'pH'), ('quality', 'density'), ('quality', 'free_sulfur_dioxide'), ('quality', 'alcohol'), ('quality', 'volatile_acidity'), ('quality', 'sulphates'), ('quality', 'residual_sugar'), ('quality', 'citric_acid'), ('quality', 'fixed_acidity'), ('quality', 'total_sulfur_dioxide')]), discovery_results=None, estimation_results=None, refutation_results=None)

# %% [markdown]
# ## Checking the Feature infered importance

# %%
problem.dataset.feature_mapping
# Out:
# [FeatureTypeMap(feature='alcohol', type=<FeatureType.CONTINUOUS: 3>, importance=0.25296813144971836),
#  FeatureTypeMap(feature='volatile_acidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.12747149434953053),
#  FeatureTypeMap(feature='free_sulfur_dioxide', type=<FeatureType.CONTINUOUS: 3>, importance=0.09022769786572933),
#  FeatureTypeMap(feature='sulphates', type=<FeatureType.CONTINUOUS: 3>, importance=0.07896145650504846),
#  FeatureTypeMap(feature='total_sulfur_dioxide', type=<FeatureType.CONTINUOUS: 3>, importance=0.07423155145523201),
#  FeatureTypeMap(feature='residual_sugar', type=<FeatureType.CONTINUOUS: 3>, importance=0.07344896313510414),
#  FeatureTypeMap(feature='pH', type=<FeatureType.CONTINUOUS: 3>, importance=0.06738578157748708),
#  FeatureTypeMap(feature='chlorides', type=<FeatureType.CONTINUOUS: 3>, importance=0.06537080664276268),
#  FeatureTypeMap(feature='citric_acid', type=<FeatureType.CONTINUOUS: 3>, importance=0.06004473273518612),
#  FeatureTypeMap(feature='fixed_acidity', type=<FeatureType.CONTINUOUS: 3>, importance=0.055258428032332364),
#  FeatureTypeMap(feature='density', type=<FeatureType.CONTINUOUS: 3>, importance=0.054630956251868826)]

# %% [markdown]
# # Causal Discovery

# %%
from causal_nest.discovery import applyable_models

models = applyable_models(problem)
models
# Out:
# [causal_nest.discovery_models.pc.PC,
#  causal_nest.discovery_models.gs.GS,
#  causal_nest.discovery_models.ccdr.CCDR,
#  causal_nest.discovery_models.iamb.IAMB,
#  causal_nest.discovery_models.sam.SAM,
#  causal_nest.discovery_models.bes.BES,
#  causal_nest.discovery_models.grasp.GRASP,
#  causal_nest.discovery_models.cgnn.CGNN]

# %%
from causal_nest.discovery import discover_with_all_models

problem = discover_with_all_models(problem, max_seconds_model=DISCOVERY_TIMEOUT_SECONDS)
problem.discovery_results
# Out:
# GRaSP edge count: 52    Function raised R Package (k)pcalg/RCIT is not available. RCIT has to be installed from https://github.com/Diviyan-Kalainathan/RCIT
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/pebble/common.py", line 174, in process_execute
#     return function(*args, **kwargs)
#   File "/app/causal-nest/causal_nest/discovery.py", line 145, in _run_discover_with_model_task
#     return discover_with_model(*args)
#   File "/app/causal-nest/causal_nest/discovery.py", line 91, in discover_with_model
#     output_graph = m.create_graph_from_data(problem.dataset)
#   File "/app/causal-nest/causal_nest/discovery_models/pc.py", line 44, in create_graph_from_data
#     m = CDT_PC()
#   File "/usr/local/lib/python3.9/site-packages/cdt/causality/graph/PC.py", line 176, in __init__
#     raise ImportError("R Package (k)pcalg/RCIT is not available. "
# ImportError: R Package (k)pcalg/RCIT is not available. RCIT has to be installed from https://github.com/Diviyan-Kalainathan/RCIT
#
# Function raised R Package bnlearn is not available.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/pebble/common.py", line 174, in process_execute
#     return function(*args, **kwargs)
#   File "/app/causal-nest/causal_nest/discovery.py", line 145, in _run_discover_with_model_task
#     return discover_with_model(*args)
#   File "/app/causal-nest/causal_nest/discovery.py", line 91, in discover_with_model
#     output_graph = m.create_graph_from_data(problem.dataset)
#   File "/app/causal-nest/causal_nest/discovery_models/gs.py", line 40, in create_graph_from_data
#     m = CDT_GS()
#   File "/usr/local/lib/python3.9/site-packages/cdt/causality/graph/bnlearn.py", line 318, in __init__
#     super(GS, self).__init__(score='NULL', alpha=0.05, beta='NULL',
#   File "/usr/local/lib/python3.9/site-packages/cdt/causality/graph/bnlearn.py", line 124, in __init__
#     raise ImportError("R Package bnlearn is not available.")
# ImportError: R Package bnlearn is not available.
#
# Function raised R Package sparsebn is not available.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/pebble/common.py", line 174, in process_execute
#     return function(*args, **kwargs)
#   File "/app/causal-nest/causal_nest/discovery.py", line 145, in _run_discover_with_model_task
#     return discover_with_model(*args)
#   File "/app/causal-nest/causal_nest/discovery.py", line 91, in discover_with_model
#     output_graph = m.create_graph_from_data(problem.dataset)
#   File "/app/causal-nest/causal_nest/discovery_models/ccdr.py", line 43, in create_graph_from_data
#     m = CDT_CCDR()
#   File "/usr/local/lib/python3.9/site-packages/cdt/causality/graph/CCDr.py", line 90, in __init__
#     raise ImportError("R Package sparsebn is not available.")
# ImportError: R Package sparsebn is not available.
#
# Function raised R Package bnlearn is not available.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/pebble/common.py", line 174, in process_execute
#     return function(*args, **kwargs)
#   File "/app/causal-nest/causal_nest/discovery.py", line 145, in _run_discover_with_model_task
#     return discover_with_model(*args)
#   File "/app/causal-nest/causal_nest/discovery.py", line 91, in discover_with_model
#     output_graph = m.create_graph_from_data(problem.dataset)
#   File "/app/causal-nest/causal_nest/discovery_models/iamb.py", line 40, in create_graph_from_data
#     m = CDT_IAMB()
#   File "/usr/local/lib/python3.9/site-packages/cdt/causality/graph/bnlearn.py", line 364, in __init__
#     super(IAMB, self).__init__(score='NULL', alpha=0.05, beta='NULL',
#   File "/usr/local/lib/python3.9/site-packages/cdt/causality/graph/bnlearn.py", line 124, in __init__
#     raise ImportError("R Package bnlearn is not available.")
# ImportError: R Package bnlearn is not available.
#
# GRaSP edge count: 47
#   0%|          | 0/1000 [00:00<?, ?it/s]
# GRaSP edge count: 43
# GRaSP completed in: 6.85s
#   0%|          | 3/1000 [00:10<56:10,  3.38s/it, disc=0.403, gen=-.25, regul_loss=0.199, tot=-4.31]

# %%
list(sorted(filter(lambda x: x, problem.discovery_results.values()), key=lambda x: x.priority_score, reverse=True))

# %% [markdown]
# # Causal Estimation

# %%
from causal_nest.estimation import estimate_all_effects

problem = estimate_all_effects(problem, verbose=True, max_seconds_model=ESTIMATION_TIMEOUT_SECONDS)
problem.estimation_results

# %% [markdown]
# # Refutation

# %%
from causal_nest.refutation import refute_all_results

problem = refute_all_results(problem, max_seconds_global=REFUTATION_GLOBAL_TIMEOUT_SECONDS, max_seconds_model=REFUTATION_MODEL_TIMEOUT_SECONDS)
problem.refutation_results

# %% [markdown]
# # Output Graphs

# %%
from causal_nest.result import generate_all_results


graphs = generate_all_results(problem)
graphs

# %%
from graphviz import Source

for k, v in graphs.items():
    print(k)

    if v is None: 
        print('No graph')
    else:
        display(Source(v))
